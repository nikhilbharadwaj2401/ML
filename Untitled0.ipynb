# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/Mall_Customers.csv')

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(n_samples = 500,n_features = 2,centers = 3,random_state = 23)

fig = plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
# prompt: apply k-means algorithm to /Mall_Customers.csv

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans = kmeans.fit(X)
labels = pd.DataFrame(kmeans.labels_,columns=['labels'])
labels
X = pd.DataFrame(X,columns=['x','y'])
df = pd.concat([X,labels],axis=1)
df
plt.figure(figsize=(10,8))
plt.scatter(df['x'],df['y'],c=kmeans.labels_,cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1], s = 300, c = 'red',label = 'Centroids')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
# prompt: apply dbscan algorithm to /Mall_Customers.csv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# Load the data
data = pd.read_csv('/Mall_Customers.csv')

# Select features for clustering (e.g., Annual Income and Spending Score)
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]

# Apply DBSCAN
dbscan = DBSCAN(eps=5, min_samples=5) # Adjust eps and min_samples as needed
dbscan.fit(X)
labels = dbscan.labels_

# Visualize the clusters
plt.figure(figsize=(10,8))
plt.scatter(X['Annual Income (k$)'], X['Spending Score (1-100)'], c=labels, cmap='viridis')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('DBSCAN Clustering')
plt.show()

# %%
# prompt: form 3 cluseters using dbscan algorithm over the datset /Mall_Customers.csv

# Assuming 'data' DataFrame is already loaded and preprocessed as in the provided code.

# Select features for clustering
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]

# Apply DBSCAN with specified parameters for 3 clusters (adjust eps and min_samples if necessary)
dbscan = DBSCAN(eps=10, min_samples=4)  # Example values, tune for optimal results
dbscan.fit(X)
labels = dbscan.labels_

# Visualize the clusters
plt.figure(figsize=(10,8))
plt.scatter(X['Annual Income (k$)'], X['Spending Score (1-100)'], c=labels, cmap='viridis')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('DBSCAN Clustering - 3 Clusters')
plt.show()

# %%
# prompt: form 5 cluseters using k means algorithm over the datset /Mall_Customers.csv

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Load the data
data = pd.read_csv('/Mall_Customers.csv')

# Select features for clustering
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]

# Apply KMeans with 5 clusters
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(X)
labels = kmeans.labels_

# Visualize the clusters
plt.figure(figsize=(10, 8))
plt.scatter(X['Annual Income (k$)'], X['Spending Score (1-100)'], c=labels, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label='Centroids')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('KMeans Clustering - 5 Clusters')
plt.legend()
plt.show()
